# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.get_option("display.max_columns",None)
df = pd.read_csv("train.csv")

df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.set_index("Id")
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe(include="all")
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %%
df.pop("Alley")
df.pop("PoolQC")
df.pop("Fence")
df.pop("MiscFeature")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
#removing columns with only one uniuqe value
df = df.loc[:,df.apply(pd.Series.nunique, axis=0)!=1]
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
#checking for variance 
for col in df.select_dtypes(include=np.number).columns:
    print(f"variance of{col} is {df.var()[col]}")
# Out:
# C:\Users\ahmed\AppData\Local\Temp/ipykernel_11972/3900481227.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(f"variance of{col} is {df.var()[col]}")
# variance ofId is 177755.0
# variance ofMSSubClass is 1789.338306402396
# variance ofLotFrontage is 589.7491687482653
# variance ofLotArea is 99625649.65034176
# variance ofOverallQual is 1.9126794482991725
# variance ofOverallCond is 1.2383223637882954
# variance ofYearBuilt is 912.2154126019886
# variance ofYearRemodAdd is 426.23282225581426
# variance ofMasVnrArea is 32784.9711678846
# variance ofBsmtFinSF1 is 208025.46846873913
# variance ofBsmtFinSF2 is 26023.90777883144
# variance ofBsmtUnfSF is 195246.40617940604
# variance ofTotalBsmtSF is 192462.36170908954
# variance of1stFlrSF is 149450.07920371433
# variance of2ndFlrSF is 190557.07533730177
# ...

# %%
# checking coorelations
df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
corr = df.corr()
# To visualize correlation
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
c_ax = ax.matshow(corr, vmin=-1, vmax=1)
fig.colorbar(c_ax)
ticks = np.arange(0,len(corr.columns.tolist()),1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(corr.columns.tolist())
ax.set_yticklabels(corr.columns.tolist())
plt.show()

# %%
# checking fro missing data
print(df.isna().sum())
df.describe(include='all')
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 77, dtype: int64
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# ...

# %%
df=df.dropna(subset=["BsmtQual","BsmtCond","BsmtExposure", "BsmtFinType1", "BsmtFinSF1","BsmtFinType2",
                     "GarageType","GarageYrBlt", "GarageFinish","GarageQual","GarageCond","MasVnrType","MasVnrArea"])

# %%
df = df.set_index("Id")

# %%
# skewness check
for col in df.select_dtypes(include=np.number).columns:
    print(f"skewness of {col} is {df[col].skew()}")
# Out:
# skewness of MSSubClass is 1.3907440123224886
# skewness of LotFrontage is 2.2280108507563936
# skewness of LotArea is 11.942666231999837
# skewness of OverallQual is 0.31651798782256674
# skewness of OverallCond is 0.8986827554536803
# skewness of YearBuilt is -0.6787385270169931
# skewness of YearRemodAdd is -0.5643474276437265
# skewness of MasVnrArea is 2.5838008828909973
# skewness of BsmtFinSF1 is 1.693580409102573
# skewness of BsmtFinSF2 is 4.148302193182214
# skewness of BsmtUnfSF is 0.9364423798711418
# skewness of TotalBsmtSF is 2.2071203139538857
# skewness of 1stFlrSF is 1.3975609349348024
# skewness of 2ndFlrSF is 0.7678343879279657
# skewness of LowQualFinSF is 10.570858743318142
# skewness of GrLivArea is 1.4313211037667128
# skewness of BsmtFullBath is 0.46111156260161007
# skewness of BsmtHalfBath is 3.849623505278384
# skewness of FullBath is -0.015561462640670614
# skewness of HalfBath is 0.5519354251937164
# skewness of BedroomAbvGr is -0.05857157061855527
# ...

# %%
remove_list = ["MSSubClass", "LotFrontage", "LotArea","MasVnrArea","BsmtFinSF1","TotalBsmtSF","1stFlrSF",
               "GrLivArea","WoodDeckSF","OpenPorchSF"]
def filter_IQR2(df, column_name):
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1
    print(f"====== {column_name} ======")
    print(f"First Quartile Q1: {Q1}")
    print(f"Third Quartile Q3: {Q3}")
    print(f"The inter-quartile range: {IQR} \n")
    
    print(f"length of data before filtering is {len(df)}")
    lower_range = Q1 - 1.5 * IQR
    upper_range = Q3 + 1.5 * IQR
    
    not_outlier_list = [val for val in df[col] if ((val >= lower_range) & (val <= upper_range))]
    filtered = df.loc[df[col].isin(not_outlier_list)]
    print(f"length of data after filtering is {len(filtered)}\n")

    return filtered.index.tolist()

index_set = set(df.index.tolist())

for col in remove_list:
    index_set = set(filter_IQR2(df, col)).intersection(index_set)
#     print(index_set)

df=df.loc[set(index_set)]
# Out:
# ====== MSSubClass ======
# First Quartile Q1: 20.0
# Third Quartile Q3: 70.0
# The inter-quartile range: 50.0
#
# length of data before filtering is 1339
# length of data after filtering is 1251
#
# ====== LotFrontage ======
# First Quartile Q1: 60.0
# Third Quartile Q3: 80.0
# The inter-quartile range: 20.0
#
# length of data before filtering is 1339
# length of data after filtering is 1014
#
# ====== LotArea ======
# First Quartile Q1: 7746.0
# Third Quartile Q3: 11757.5
# The inter-quartile range: 4011.5
#
# length of data before filtering is 1339
# length of data after filtering is 1263
#
# ====== MasVnrArea ======
# First Quartile Q1: 0.0
# Third Quartile Q3: 174.0
# The inter-quartile range: 174.0
#
# length of data before filtering is 1339
# length of data after filtering is 1257
#
# ====== BsmtFinSF1 ======
# First Quartile Q1: 0.0
# Third Quartile Q3: 733.0
# The inter-quartile range: 733.0
#
# length of data before filtering is 1339
# length of data after filtering is 1333
# ...

# %%
# skewness check
for col in df.select_dtypes(include=np.number).columns:
    print(f"skewness of {col} is {df[col].skew()}")
# Out:
# skewness of MSSubClass is 0.9170189760202567
# skewness of LotFrontage is 0.0941464352718206
# skewness of LotArea is 0.2327858322284647
# skewness of OverallQual is 0.2349667957822674
# skewness of OverallCond is 0.7549507430979834
# skewness of YearBuilt is -0.4630601180437588
# skewness of YearRemodAdd is -0.525257757800572
# skewness of MasVnrArea is 1.4362651093542727
# skewness of BsmtFinSF1 is 0.6651483543513675
# skewness of BsmtFinSF2 is 4.466324182240491
# skewness of BsmtUnfSF is 0.7811964328075179
# skewness of TotalBsmtSF is 0.545538288641485
# skewness of 1stFlrSF is 0.6388854759246358
# skewness of 2ndFlrSF is 0.8423422779458463
# skewness of LowQualFinSF is 10.599878573109937
# skewness of GrLivArea is 0.49549935062938455
# skewness of BsmtFullBath is 0.5481854287424648
# skewness of BsmtHalfBath is 4.039597246666301
# skewness of FullBath is 0.03326251533938159
# skewness of HalfBath is 0.8944368728398366
# skewness of BedroomAbvGr is -0.026566593617817016
# ...

# %%
corr = df.corr()
# To visualize correlation
# fig = plt.figure()
# ax = fig.add_axes([0, 0, 1, 1])
# c_ax = ax.matshow(corr, vmin=-1, vmax=1)
# fig.colorbar(c_ax)
# ticks = np.arange(0,len(corr.columns.tolist()),1)
# ax.set_xticks(ticks)
# ax.set_yticks(ticks)
# ax.set_xticklabels(corr.columns.tolist())
# ax.set_yticklabels(corr.columns.tolist())
# plt.show()
print(corr)
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.302081 -0.263817     0.196698    -0.070224
# LotFrontage     -0.302081     1.000000  0.527016     0.209596    -0.079672
# LotArea         -0.263817     0.527016  1.000000     0.211252    -0.096329
# OverallQual      0.196698     0.209596  0.211252     1.000000    -0.225034
# OverallCond     -0.070224    -0.079672 -0.096329    -0.225034     1.000000
# YearBuilt        0.080989     0.216162  0.175289     0.624135    -0.434567
# YearRemodAdd     0.091432     0.090806  0.117450     0.552014     0.019584
# MasVnrArea       0.022075     0.338184  0.171760     0.376811    -0.181287
# BsmtFinSF1      -0.021885     0.124005  0.123173     0.175015    -0.058604
# BsmtFinSF2      -0.049919     0.054151  0.009114    -0.110803     0.055417
# BsmtUnfSF       -0.054741     0.040027  0.032226     0.281576    -0.203723
# ...

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %%
df.pop("BsmtFinSF2")
df.pop("BsmtHalfBath")
df.pop("KitchenAbvGr")
df.pop("3SsnPorch")
df.pop("ScreenPorch")
df.pop("PoolArea")
df.pop("MiscVal")
df.pop("MoSold")
df.pop("YrSold")
# Out:
# Id
# 1       2008
# 2       2007
# 3       2008
# 4       2006
# 5       2008
#         ...
# 1455    2009
# 1456    2007
# 1457    2010
# 1458    2010
# 1459    2010
# Name: YrSold, Length: 842, dtype: int64

# %%
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# Id
# 1             60       RL         65.0     8450   Pave      Reg         Lvl
# 2             20       RL         80.0     9600   Pave      Reg         Lvl
# 3             60       RL         68.0    11250   Pave      IR1         Lvl
# 4             70       RL         60.0     9550   Pave      IR1         Lvl
# 5             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          20       FV         62.0     7500   Pave      Reg         Lvl
# 1456          60       RL         62.0     7917   Pave      Reg         Lvl
# 1457          20       RL         85.0    13175   Pave      Reg         Lvl
# 1458          70       RL         66.0     9042   Pave      Reg         Lvl
# 1459          20       RL         68.0     9717   Pave      Reg         Lvl
#
# ...

# %%
print(df.duplicated(keep='first'),"\n")
print(df[df.duplicated()],'\n')
# Out:
# Id
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Length: 842, dtype: bool
#
# Empty DataFrame
# ...

# %%
# checking fro missing data
print(df.isna().sum())
df.describe(include='all')
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# OpenPorchSF      0
# EnclosedPorch    0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 67, dtype: int64
#         MSSubClass MSZoning  LotFrontage       LotArea Street LotShape  \
# count   842.000000      842   842.000000    842.000000    842      842
# unique         NaN        5          NaN           NaN      2        4
# top            NaN       RL          NaN           NaN   Pave      Reg
# freq           NaN      677          NaN           NaN    840      601
# mean     47.410926      NaN    68.866983   9259.480998    NaN      NaN
# std      29.297275      NaN    15.243919   2566.692904    NaN      NaN
# min      20.000000      NaN    30.000000   2500.000000    NaN      NaN
# 25%      20.000000      NaN    60.000000   7747.250000    NaN      NaN
# 50%      50.000000      NaN    70.000000   9100.000000    NaN      NaN
# ...

# %%
df["Electrical"]
# Out:
# Id
# 1       SBrkr
# 2       SBrkr
# 3       SBrkr
# 4       SBrkr
# 5       SBrkr
#         ...
# 1455    SBrkr
# 1456    SBrkr
# 1457    SBrkr
# 1458    SBrkr
# 1459    FuseA
# Name: Electrical, Length: 842, dtype: object

# %%
df["FireplaceQu"] = df["FireplaceQu"].fillna(value=df["FireplaceQu"].mode()[0])

# %%
df["Electrical"] = df["Electrical"].fillna(value=df["Electrical"].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 842 entries, 1 to 1459
# Data columns (total 67 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     842 non-null    int64
#  1   MSZoning       842 non-null    object
#  2   LotFrontage    842 non-null    float64
#  3   LotArea        842 non-null    int64
#  4   Street         842 non-null    object
#  5   LotShape       842 non-null    object
#  6   LandContour    842 non-null    object
#  7   Utilities      842 non-null    object
#  8   LotConfig      842 non-null    object
#  9   LandSlope      842 non-null    object
#  10  Neighborhood   842 non-null    object
#  11  Condition1     842 non-null    object
#  12  Condition2     842 non-null    object
#  13  BldgType       842 non-null    object
#  14  HouseStyle     842 non-null    object
#  15  OverallQual    842 non-null    int64
#  16  OverallCond    842 non-null    int64
# ...

# %%
print(len(df.columns))

for cols in df.select_dtypes(include=np.number).columns:
    column_1 = df[cols]
    column_2 = df["SalePrice"]
    correlation = column_1.corr(column_2)
    
    if correlation < 0.5 and correlation > 0:
        df.pop(cols)
    if correlation > -0.5 and correlation < 0:
        df.pop(cols)
        
print(len(df.columns))
# Out:
# 67
# 51

# %%
# normalization 
from sklearn.preprocessing import Normalizer
scaler = Normalizer(norm='l1')

df2 = df.copy()
df2.loc[:, df2.select_dtypes(include=np.number).columns] = scaler.fit_transform(df.loc[:, df2.select_dtypes(include=np.number).columns])
df2
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 2          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 5          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       FV   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... GarageYrBlt GarageFinish  \
# ...

# %%
import category_encoders as ce
df3 = df2.copy()
enc = ce.OrdinalEncoder(cols=df3.select_dtypes(include=object).columns.tolist())


df3 = enc.fit_transform(df3)
df3
# Out:
#       MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  \
# Id
# 1            1       1         1            1          1          1
# 2            1       1         1            1          1          2
# 3            1       1         2            1          1          1
# 4            1       1         2            1          1          3
# 5            1       1         2            1          1          2
# ...        ...     ...       ...          ...        ...        ...
# 1455         4       1         1            1          1          1
# 1456         1       1         1            1          1          1
# 1457         1       1         1            1          1          1
# 1458         1       1         1            1          1          1
# 1459         1       1         1            1          1          1
#
#       LandSlope  Neighborhood  Condition1  Condition2  ...  GarageYrBlt  \
# Id                                                     ...
# ...

# %%
df3
# Out:
#       MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  \
# Id
# 1            1       1         1            1          1          1
# 2            1       1         1            1          1          2
# 3            1       1         2            1          1          1
# 4            1       1         2            1          1          3
# 5            1       1         2            1          1          2
# ...        ...     ...       ...          ...        ...        ...
# 1455         4       1         1            1          1          1
# 1456         1       1         1            1          1          1
# 1457         1       1         1            1          1          1
# 1458         1       1         1            1          1          1
# 1459         1       1         1            1          1          1
#
#       LandSlope  Neighborhood  Condition1  Condition2  ...  GarageYrBlt  \
# Id                                                     ...
# ...

# %%
import sklearn 

Y = df3.filter(["SalePrice"], axis = 1)
Y.shape

X = df3.drop("SalePrice", 1)
X.shape
# Out:
# C:\Users\ahmed\AppData\Local\Temp/ipykernel_11972/4166193594.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X = df3.drop("SalePrice", 1)
# (842, 50)

# %%
from sklearn.model_selection import train_test_split
train_features, validation_features, train_output, validation_output = train_test_split(X,Y,test_size= 0.33, random_state=42)

# %%
print(train_features.shape)
print(validation_features.shape)
print(train_output.shape)
print(validation_output.shape)
# Out:
# (564, 50)
# (278, 50)
# (564, 1)
# (278, 1)

# %%
from sklearn.linear_model import LinearRegression
# from sklearn import mean_absolute_error, mean_squared_error

# instantiate the model (using the default parameters)
reg = LinearRegression()

reg.fit(train_features, train_output)

y_pred = reg.predict(train_features)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print("MSE=",mean_squared_error(train_output, y_pred))
print("MAE=",mean_absolute_error(train_output, y_pred))
# Out:
# MSE= 2.1517090338109468e-30
# MAE= 7.539280468642464e-16

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)
X_transformed = poly.fit_transform(train_features)

polyn = LinearRegression()
polyn.fit(X_transformed,train_output)
pred = polyn.predict(X_transformed)


print("MSE=",mean_squared_error(train_output, pred))
print("MAE=",mean_absolute_error(train_output, pred))
# Out:
# MSE= 7.247397312427747e-31
# MAE= 6.724329525034636e-16

# %%
# Visualization
X_sorted, Y_pred = zip(*sorted(zip(train_features, pred), key=lambda x: x[0]))

plt.plot(train_features, train_output, 'ro', ms=10, mec='k')

plt.plot(X_sorted, Y_pred, 'b')

plt.title('Polynomial Regression')

plt.xlabel('X')

plt.ylabel('Y')

plt.show()
